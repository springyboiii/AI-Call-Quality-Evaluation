# %% [markdown]
# # AI vs Human Evaluation

# %%
import sys
sys.path.append('../../')
from src.clients.postgres_client import PostgresClient

db = PostgresClient()
evaluations = db.get_evaluations()
print(evaluations)
# Out:
# [{'id': '1d40f1b8-05e3-484c-9215-f60bdf691848', 'call_id': '8f18f353-4b4b-4f98-8b02-d5d9cc5a62e4', 'evaluator_type': 'agentic', 'evaluator_version': '0.1', 'overall_score': 1, 'category_scores': {'empathy_and_tone': {'score': 2, 'evidence': '"53.0 Okay. Wonderful."', 'explanation': 'Tone is neutral; minimal expressions of empathy are present.'}, 'problem_resolution': {'score': 1, 'evidence': '"458.0 I have it downloaded already."', 'explanation': "The call does not resolve the customer's issue or provide a clear solution."}, 'call_closure_quality': {'score': 2, 'evidence': '"687.0 Thank you so much."', 'explanation': 'Closure is brief but lacks a proper summary or confirmation.'}, 'compliance_statements': {'score': 1, 'evidence': 'Not present', 'explanation': 'No compliance or regulatory statements were made.'}, 'customer_satisfaction': {'score': 1, 'evidence': 'Not present', 'explanation': 'No explicit check for satisfaction; customer responses are minimal.'}, 'greeting_and_introduction': {'score': 2, 'evidence': '"4.0 Hello, my name is Rick and I\'m here."', 'explanation': 'Agent repeats greetings but does not clearly introduce themselves or the purpose.'}, 'product_information_accuracy': {'score': 1, 'evidence': '"25.0 So, I think we finally found an option and that\'s why I\'m calling you to help you with that."', 'explanation': 'Information provided is confusing and likely inaccurate; no clear product details.'}}, 'strengths': ['"4.0 Hello, my name is Rick and I\'m here."', '"53.0 Okay. Wonderful."'], 'improvements': ['Include clear compliance statements and regulatory disclosures.', 'Provide accurate product information and a concise resolution plan.'], 'raw_output': {'strengths': ['"4.0 Hello, my name is Rick and I\'m here."', '"53.0 Okay. Wonderful."'], 'overall_score': 1, 'category_scores': {'empathy_and_tone': {'score': 2, 'evidence': '"53.0 Okay. Wonderful."', 'explanation': 'Tone is neutral; minimal expressions of empathy are present.'}, 'problem_resolution': {'score': 1, 'evidence': '"458.0 I have it downloaded already."', 'explanation': "The call does not resolve the customer's issue or provide a clear solution."}, 'call_closure_quality': {'score': 2, 'evidence': '"687.0 Thank you so much."', 'explanation': 'Closure is brief but lacks a proper summary or confirmation.'}, 'compliance_statements': {'score': 1, 'evidence': 'Not present', 'explanation': 'No compliance or regulatory statements were made.'}, 'customer_satisfaction': {'score': 1, 'evidence': 'Not present', 'explanation': 'No explicit check for satisfaction; customer responses are minimal.'}, 'greeting_and_introduction': {'score': 2, 'evidence': '"4.0 Hello, my name is Rick and I\'m here."', 'explanation': 'Agent repeats greetings but does not clearly introduce themselves or the purpose.'}, 'product_information_accuracy': {'score': 1, 'evidence': '"25.0 So, I think we finally found an option and that\'s why I\'m calling you to help you with that."', 'explanation': 'Information provided is confusing and likely inaccurate; no clear product details.'}}, 'areas_for_improvement': ['Include clear compliance statements and regulatory disclosures.', 'Provide accurate product information and a concise resolution plan.']}, 'human_output': {'strengths': ["Agent attempts to guide customer through technical steps: '00:04:52You're gonna see a checkbox here. Please accept them.'", "Agent adapts to customer’s device limitations: '00:06:30You have Samsung. Oh, that would be that would be wonderful.'"], 'overall_score': 2, 'category_scores': {'empathy_and_tone': {'score': 2, 'evidence': '00:11:18Okay. Alright. No problem. No problem.', 'explanation': 'Tone is neutral, lacks warmth; minimal empathy shown despite customer difficulties.'}, 'problem_resolution': {'score': 1, 'evidence': '00:10:36And let me open the QR. Okay. Not available in your country.', 'explanation': 'No resolution achieved; call ends with issue unresolved.'}, 'call_closure_quality': {'score': 2, 'eviden ...

# %%
from typing import Dict, Any
import json

def compare_category_scores(human_output: Dict[str, Any], raw_output: Dict[str, Any]) -> Dict[str, Any]:
    """
    Compare category scores between human_output and raw_output.
    
    Args:
        human_output: Dictionary containing human evaluation output.
        raw_output: Dictionary containing raw (automated) evaluation output.
    
    Returns:
        Dictionary summarizing differences in category scores.
    """
    # Extract category scores
    human_scores = human_output.get("category_scores", {})
    raw_scores = raw_output.get("category_scores", {})
    
    # Initialize result
    comparison = {
        "matching_categories": [],
        "similar_categories": [],
        "differing_categories": [],
        "missing_in_human": [],
        "missing_in_raw": []
    }
    
    # Get all unique category names
    all_categories = set(human_scores.keys()).union(set(raw_scores.keys()))
    
    for category in all_categories:
        human_data = human_scores.get(category)
        raw_data = raw_scores.get(category)
        
        # Check for missing categories
        if human_data is None:
            comparison["missing_in_human"].append(category)
            continue
        if raw_data is None:
            comparison["missing_in_raw"].append(category)
            continue
        
        # Compare scores
        human_score = human_data.get("score")
        raw_score = raw_data.get("score")
        
        if human_score == raw_score:
            comparison["matching_categories"].append({
                "category": category,
                "score": human_score
            })
        elif abs(human_score - raw_score) >= 2:
            comparison["differing_categories"].append({
                "category": category,
                "human_score": human_score,
                "human_explanation": human_data.get("explanation"),
                "human_evidence": human_data.get("evidence"),
                "raw_score": raw_score,
                "raw_explanation": raw_data.get("explanation"),
                "raw_evidence": raw_data.get("evidence")
            })
        else:
            comparison["similar_categories"].append({
                "category": category,
                "human_score": human_score,
                "human_explanation": human_data.get("explanation"),
                "human_evidence": human_data.get("evidence"),
                "raw_score": raw_score,
                "raw_explanation": raw_data.get("explanation"),
                "raw_evidence": raw_data.get("evidence")
            })
    
    return comparison

for evaluation in evaluations:
    # Compare category scores
    result = compare_category_scores(evaluation["human_output"], evaluation["raw_output"])

    # Pretty print the result
    print(json.dumps(result, indent=2))
# Out:
# {
#   "matching_categories": [
#     {
#       "category": "problem_resolution",
#       "score": 1
#     },
#     {
#       "category": "call_closure_quality",
#       "score": 2
#     },
#     {
#       "category": "empathy_and_tone",
#       "score": 2
#     },
#     {
#       "category": "compliance_statements",
#       "score": 1
#     }
#   ],
#   "similar_categories": [
#     {
#       "category": "greeting_and_introduction",
#       "human_score": 3,
#       "human_explanation": "Agent introduces themselves and purpose but lacks warmth and clarity.",
#       "human_evidence": "00:00:08Hello. My name is Steven. I'm calling you from finance department of ______, but online company.",
#       "raw_score": 2,
#       "raw_explanation": "Agent repeats greetings but does not clearly introduce themselves or the purpose.",
#       "raw_evidence": "\"4.0 Hello, my name is Rick and I'm here.\""
#     },
#     {
#       "category": "product_information_accuracy",
#       "human_score": 2,
#       "human_explanation": "Instructions for AnyDesk and app setup are vague; accuracy unclear due to technical issues.",
#       "human_evidence": "00:06:30You have Samsung. Oh, that would be that would be wonderful. Can you download any desk on your Samsung phone? Because Pixel is not allowing it. Only Samsung and Motorola do",
#       "raw_score": 1,
#       "raw_explanation": "Information provided is confusing and likely inaccurate; no clear product details.",
#       "raw_evidence": "\"25.0 So, I think we finally found an option and that's why I'm calling you to help you with that.\""
#     },
#     {
#       "category": "customer_satisfaction",
#       "human_score": 2,
#       "human_explanation": "Customer follows instructions but expresses no satisfaction; issue unresolved.",
#       "human_evidence": "00:11:07Wow. Is it like you have a VPN or something?",
#       "raw_score": 1,
#       "raw_explanation": "No explicit check for satisfaction; customer responses are minimal.",
#       "raw_evidence": "Not present"
#     }
#   ],
#   "differing_categories": [],
#   "missing_in_human": [],
#   "missing_in_raw": []
# }
# {
#   "matching_categories": [],
#   "similar_categories": [
#     {
#       "category": "greeting_and_introduction",
#       "human_score": 2,
#       "human_explanation": "Agent acknowledges customer but lacks formal greeting or clear introduction.",
#       "human_evidence": "00:00:17Hello? Benjamin. Yes. Hi, Jorgen. Hello.",
#       "raw_score": 1,
#       "raw_explanation": "The agent does not provide a clear greeting or introduction to the customer.",
#       "raw_evidence": "\"0.0 Hello.\""
#     },
#     {
#       "category": "problem_resolution",
#       "human_score": 2,
#       "human_explanation": "Agent suggests messaging Atomic for resolution but no immediate solution provided.",
#       "human_evidence": "00:08:20Yes. Of course. That was my original suggestion. The best thing would be, of course, to shoot them a message and tell them would it be possible to get it done like this.",
#       "raw_score": 1,
#       "raw_explanation": "No clear resolution to the customer's issue was provided.",
#       "raw_evidence": "\"822.0 I'm going to check everything with them.\""
#     },
#     {
#       "category": "empathy_and_tone",
#       "human_score": 3,
#       "human_explanation": "Agent maintains a neutral, professional tone; limited empathy shown.",
#       "human_evidence": "00:00:24Yeah. Sorry. We we take the phone and then it disconnects. Sorry about that.",
#       "raw_score": 2,
#       "raw_explanation": "Some attempts at empathy are present but inconsistent and often irrelevant.",
#       "raw_evidence": "\"26.0 Sorry about that.\""
#     },
#     {
#       "category": "customer_satisfaction",
#       "human_score": 3,
#       "human_explanation": "Customer engages and agrees but expresses no explicit satisfaction.",
#       "human_evidence": "00:07:07I agree.",
#       "raw_score": 2,
#       "raw_explanation": "The agent does not explicitly gauge or address customer satisfaction.",
#       "raw_evidence": "\"829.0 Good. Thanks so much.\""
#     }
#   ],
#   "differing_categories": [
#     {
#       "category": "call_closure_quality",
#       "human_score": 3,
#       "human_explanation": "Closure is polite with follow-up action but lacks confirmation of customer understanding.",
#       "human_evidence": "00:13:41But please double check everything with them. Shoot them a message as soon as they reply. Send me a screenshot, and I'll and I'll get back with you.",
#       "raw_score": 1,
#       "raw_explanation": "Closure is abrupt with no summary or confirmation of next steps.",
#       "raw_evidence": "\"832.0 Okay, bye again.\""
#     },
#     {
#       "category": "product_information_accuracy",
#       "human_score": 4,
#       "human_explanation": "Agent provides detailed tax and transfer information but admits limited personal knowledge.",
#       "human_evidence": "00:09:10Capital You would have income tax only if you are licensed and registered day traders. Meaning, you do this for a living.",
#       "raw_score": 2,
#       "raw_explanation": "The agent provides confusing and potentially inaccurate information about taxes and transfers.",
#       "raw_evidence": "\"63.0 So the taxes are included in this particular amount of cash that they're asking of you.\""
#     },
#     {
#       "category": "compliance_statements",
#       "human_score": 3,
#       "human_explanation": "Agent provides a disclaimer but lacks formal compliance statements.",
#       "human_evidence": "00:03:34I have to give you a disclaimer. It's speculation. Right? A very educated speculation, let's put it this way.",
#       "raw_score": 1,
#       "raw_explanation": "No compliance statements or disclosures were made.",
#       "raw_evidence": "Not present"
#     }
#   ],
#   "missing_in_human": [],
#   "missing_in_raw": []
# }

# %%
from typing import Dict, Any, List
import numpy as np
import pandas as pd
from scipy.stats import spearmanr
from sklearn.metrics import cohen_kappa_score


def extract_scores(evaluations: List[Dict[str, Any]]) -> pd.DataFrame:
    """
    Flatten human vs AI scores into a dataframe.
    """
    rows = []

    for ev in evaluations:
        human_scores = ev["human_output"]["category_scores"]
        ai_scores = ev["raw_output"]["category_scores"]

        for category, h_data in human_scores.items():
            if category not in ai_scores:
                continue

            rows.append({
                "call_id": ev.get("call_id"),
                "category": category,
                "human_score": h_data["score"],
                "ai_score": ai_scores[category]["score"]
            })

    return pd.DataFrame(rows)


def calculate_alignment_metrics(df: pd.DataFrame) -> Dict[str, Any]:
    """
    Calculate alignment metrics overall and per category.
    """
    report = {}

    # --- Overall metrics ---
    abs_diff = np.abs(df["human_score"] - df["ai_score"])

    overall = {
        "mean_absolute_error": abs_diff.mean(),
        "accuracy_within_1": (abs_diff <= 1).mean(),
        "accuracy_exact_match": (abs_diff == 0).mean(),
        "spearman_correlation": spearmanr(
            df["human_score"], df["ai_score"]
        ).correlation,
        "cohen_kappa": cohen_kappa_score(
            df["human_score"], df["ai_score"], weights="quadratic"
        )
    }

    report["overall"] = overall

    # --- Per-category metrics ---
    per_category = {}

    for category, group in df.groupby("category"):
        diff = np.abs(group["human_score"] - group["ai_score"])

        per_category[category] = {
            "mean_absolute_error": diff.mean(),
            "accuracy_within_1": (diff <= 1).mean(),
            "spearman_correlation": spearmanr(
                group["human_score"], group["ai_score"]
            ).correlation if len(group) > 1 else None,
            "cohen_kappa": cohen_kappa_score(
                group["human_score"], group["ai_score"], weights="quadratic"
            ) if len(group) > 1 else None,
            "num_samples": len(group)
        }

    report["per_category"] = per_category

    return report

# %%
df = extract_scores(evaluations)
report = calculate_alignment_metrics(df)

import json
print(json.dumps(report, indent=2))
# Out:
# {
#   "overall": {
#     "mean_absolute_error": 0.9285714285714286,
#     "accuracy_within_1": 0.7857142857142857,
#     "accuracy_exact_match": 0.2857142857142857,
#     "spearman_correlation": 0.4970674233862171,
#     "cohen_kappa": 0.23121387283236972
#   },
#   "per_category": {
#     "call_closure_quality": {
#       "mean_absolute_error": 1.0,
#       "accuracy_within_1": 0.5,
#       "spearman_correlation": -0.9999999999999999,
#       "cohen_kappa": -0.33333333333333326,
#       "num_samples": 2
#     },
#     "compliance_statements": {
#       "mean_absolute_error": 1.0,
#       "accuracy_within_1": 0.5,
#       "spearman_correlation": NaN,
#       "cohen_kappa": 0.0,
#       "num_samples": 2
#     },
#     "customer_satisfaction": {
#       "mean_absolute_error": 1.0,
#       "accuracy_within_1": 1.0,
#       "spearman_correlation": 0.9999999999999999,
#       "cohen_kappa": 0.33333333333333337,
#       "num_samples": 2
#     },
#     "empathy_and_tone": {
#       "mean_absolute_error": 0.5,
#       "accuracy_within_1": 1.0,
#       "spearman_correlation": NaN,
#       "cohen_kappa": 0.0,
#       "num_samples": 2
#     },
#     "greeting_and_introduction": {
#       "mean_absolute_error": 1.0,
#       "accuracy_within_1": 1.0,
#       "spearman_correlation": 0.9999999999999999,
#       "cohen_kappa": 0.33333333333333337,
#       "num_samples": 2
#     },
#     "problem_resolution": {
#       "mean_absolute_error": 0.5,
#       "accuracy_within_1": 1.0,
#       "spearman_correlation": NaN,
#       "cohen_kappa": 0.0,
#       "num_samples": 2
#     },
#     "product_information_accuracy": {
#       "mean_absolute_error": 1.5,
#       "accuracy_within_1": 0.5,
#       "spearman_correlation": 0.9999999999999999,
#       "cohen_kappa": 0.33333333333333337,
#       "num_samples": 2
#     }
#   }
# }
# C:\Users\sugum\AppData\Local\Temp\ipykernel_34156\3641306479.py:64: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   "spearman_correlation": spearmanr(
# C:\Users\sugum\AppData\Local\Temp\ipykernel_34156\3641306479.py:64: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   "spearman_correlation": spearmanr(
# C:\Users\sugum\AppData\Local\Temp\ipykernel_34156\3641306479.py:64: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   "spearman_correlation": spearmanr(

# %% [markdown]
# # Transcription accuracy

# %%
import sys
sys.path.append('../../')
from src.clients.postgres_client import PostgresClient

db = PostgresClient()
transcripts = db.get_transcripts()
print(transcripts)
# Out:
# [{'id': '864e752d-6697-435e-b145-8ea20ffdc93e', 'call_id': '9b065473-bc1d-46bc-a1ae-15b09afd2a3b', 'transcript_text': " I think it was not even released for money necessarily for atomic content at different organizations. Hello? Here's a man. Hello? Here's a man. Yes, Hi, sir. And hello, I called the... That's a lot to go. Yeah, sorry. We just came back. Sorry about that. Oh, really? I don't know. Yeah, sorry, we taste your corn and then it just connects. Sorry about that. Oh really? I don't have a sword now. I got the chalacious now. Okay. Well, at least we got each other right here right now. Listen, you're dead. As I was told by my finance team, they looked into this. Now, I personally do with atomic, but I should be honest, I never cashed out. I stocked by a monster all in atomic. Can I remove anything out of atomic? Right? Let's put a disc lane. So my knowledge, personal knowledge, maybe limited. But I'm checking everything up with my finance team and they're telling me that the taxes are included in this money. So the taxes are included in this particular amount of cash that they're asking of you. Now, how are they planning to refund it? I have no idea. Right? That's something that I must not explain. But the money that is supposed to be coming in, who your account and most likely the next step will be to ask you for the payment details, I suppose. Like where is the money going to be sending to? The money will be coming in from an account that is not related to crypto. That is the reason how they justify. And they say, that's how you don't pay taxes after the money comes in to your account. You understand? Because the transfer has nothing to do with crypto currency. The cash health itself, if you understand what I mean. Yeah, so what I don't understand, Benjamin, is what we are doing. Well, personal, my next question is, is the envy transfer back to index as we planned? Like it says? Yes. And then convert it. Well, this is something that has to be done with atomic support. I suppose it is possible. I've seen a reason why it wouldn't be possible. But if you can shoot them, I'm not interested in having this transferred to the dollar. Canadian, I'm going to transfer it over to index by myself. But whether that's possible, like you already read it. So that kind of a message. Yes, they are. Because of in terms of taxes, when you get it back to index, when you do it on our account, you put it in a special account. And you must say, whatever we have invested, we don't have to pay taxes. Wait, wait, wait, wait. Just to correct you over there. Okay? Any money coming in, the dollar can aid in, from index, right? In fact, there is no debate about it. Okay, the question is from what type of account or from what business is the money coming in? And then that being one of Canada's largest cryptocurrency case here, that money will be taxable at some point. Do you understand? Yes, it will be okay. 100%. There is no debate about it. Why do we even $100? It's taxable. Do you understand? Okay, there is no debate about it. And given that you have, that you're withdrawing, reported what you've invested, right, you will have taxes. There is no question about it. Now, what atomic as I was explained over here about my finances, what atomic is offering, I mean, it's not clearly explained. So let's put it this way. I have to give you a disclaimer. It's a speculation, right? A very educated speculation, let's put it this way. It can be clarified very much, I guess, in a future couple of messages. But one of my guess is that it's going to be a Canada transfer from their account to your account. Their account that they will use will not have any kind of relations to cryptocurrency whatsoever. There goes the transfer that they're doing to you will be not taxable. Now, how are they going to justify giving you this feedback? I have no idea, to be honest. This is not what they might need to understand. I really don't clarify because in the free show tha ...

# %%
# jiwer library
import jiwer
import re

def normalize_text(text: str) -> str:
    text = text.lower()
    text = re.sub(r"\[.*?\]", "", text)          # remove annotations
    text = re.sub(r"\d+:\d+:\d+", "", text)      # remove timestamps
    text = re.sub(r"[^a-z0-9\s']", "", text)     # remove punctuation
    text = re.sub(r"\s+", " ", text).strip()
    return text

transformation = jiwer.Compose([
    jiwer.ToLowerCase(),
    jiwer.RemovePunctuation(),
    jiwer.RemoveMultipleSpaces(),
    jiwer.Strip(),
    jiwer.ReduceToListOfListOfWords(word_delimiter=" ")
])

for transcript in transcripts:
    print(jiwer.wer(normalize_text(transcript['human_transcript']), normalize_text(transcript['timestamped_text']), reference_transform=transformation,
    hypothesis_transform=transformation))
# Out:
# 0.3017312448474856
# 0.4485887096774194
